# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\ojas2\OneDrive\Desktop\TUF\b.tech\data sciences\project 35\repo csv dtst.csv",)

# %%
df.head()
# Out:
#    Unnamed: 0       Entity Code  Year  Self-harm  \
# 0           0  Afghanistan  AFG  1990   0.305874
# 1           1  Afghanistan  AFG  1991   0.312853
# 2           2  Afghanistan  AFG  1992   0.328217
# 3           3  Afghanistan  AFG  1993   0.332590
# 4           4  Afghanistan  AFG  1994   0.324567
#
#    Exposure to forces of nature  Conflict and terrorism  \
# 0                      0.007185                3.688980
# 1                      0.662918                4.598062
# 2                      0.293873                4.939704
# 3                      0.114703                4.546126
# 4                      0.084153                6.225331
#
#    Interpersonal violence  Neglected tropical diseases and malaria  \
# 0                0.829299                                 1.118338
# 1                1.007482                                 1.136197
# 2                1.057353                                 1.100388
# ...

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
pd.set_option('display.max_columns', 50)

# %%
df_world=df[df['Entity']=='World']
df_world=df_world.drop(['Entity','Code'],axis=1)
df_world=df_world.set_index('Year')
df_world.head(1)
# Out:
#       Self-harm  Exposure to forces of nature  Conflict and terrorism  \
# Year
# 1990   1.394316                      0.125991                0.362549
#
#       Interpersonal violence  Neglected tropical diseases and malaria  \
# Year
# 1990                0.943874                                  3.64122
#
#       Substance use disorders  Skin and subcutaneous diseases  \
# Year
# 1990                 0.873035                        1.181055
#
#       Enteric infections  Diabetes and kidney diseases  \
# Year
# 1990            8.130332                      1.957389
#
#       Cardiovascular diseases  Digestive diseases  Nutritional deficiencies  \
# Year
# 1990                10.798273            2.779966                   3.38308
#
#       Respiratory infections and tuberculosis  Neonatal disorders  \
# Year
# 1990                                12.067338            10.58811
#
#       Chronic respiratory diseases  Other non-communicable diseases  \
# Year
# ...

# %%
df_world.tail(1)
# Out:
#       Self-harm  Exposure to forces of nature  Conflict and terrorism  \
# Year
# 2019   1.347542                      0.037874                0.247053
#
#       Interpersonal violence  Neglected tropical diseases and malaria  \
# Year
# 2019                1.064333                                 2.479057
#
#       Substance use disorders  Skin and subcutaneous diseases  \
# Year
# 2019                 1.383094                        1.682409
#
#       Enteric infections  Diabetes and kidney diseases  \
# Year
# 2019            3.817623                      4.440245
#
#       Cardiovascular diseases  Digestive diseases  Nutritional deficiencies  \
# Year
# 2019                15.518859            3.509795                  1.954337
#
#       Respiratory infections and tuberculosis  Neonatal disorders  \
# Year
# 2019                                 6.035898            7.330184
#
#       Chronic respiratory diseases  Other non-communicable diseases  \
# Year
# ...

# %%
df_world.plot(figsize=(15,15))
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=10)

# %%
df_world_high=df[df['Entity']=='United States']
df_world_high=df_world_high.drop(['Entity','Code'],axis=1)
df_world_high=df_world_high.set_index('Year')
df_world_high.head(1)
# Out:
#       Self-harm  Exposure to forces of nature  Conflict and terrorism  \
# Year
# 1990   1.886517                      0.013626                0.001667
#
#       Interpersonal violence  Neglected tropical diseases and malaria  \
# Year
# 1990                1.967326                                 0.085749
#
#       Substance use disorders  Skin and subcutaneous diseases  \
# Year
# 1990                 2.803013                        2.069175
#
#       Enteric infections  Diabetes and kidney diseases  \
# Year
# 1990            0.257246                       3.58651
#
#       Cardiovascular diseases  Digestive diseases  Nutritional deficiencies  \
# Year
# 1990                19.828922            3.092327                  0.343164
#
#       Respiratory infections and tuberculosis  Neonatal disorders  \
# Year
# 1990                                 1.959975            2.635396
#
#       Chronic respiratory diseases  Other non-communicable diseases  \
# Year
# ...

# %%
df_world_high.tail(1)
# Out:
#       Self-harm  Exposure to forces of nature  Conflict and terrorism  \
# Year
# 2019   1.719949                      0.005537                0.005198
#
#       Interpersonal violence  Neglected tropical diseases and malaria  \
# Year
# 2019                1.080802                                 0.090004
#
#       Substance use disorders  Skin and subcutaneous diseases  \
# Year
# 2019                 6.662409                        1.973523
#
#       Enteric infections  Diabetes and kidney diseases  \
# Year
# 2019            0.399487                       6.07536
#
#       Cardiovascular diseases  Digestive diseases  Nutritional deficiencies  \
# Year
# 2019                15.591722            3.308953                  0.369548
#
#       Respiratory infections and tuberculosis  Neonatal disorders  \
# Year
# 2019                                 1.485538            1.435551
#
#       Chronic respiratory diseases  Other non-communicable diseases  \
# Year
# ...

# %%
df_world_high.plot(figsize=(15,15))
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=10)

# %%
df_world_low=df[df['Entity']=='World Bank Low Income']
df_world_low=df_world_low.drop(['Entity','Code'],axis=1)
df_world_low=df_world_low.set_index('Year')
df_world_low.head(1)
# Out:
#       Self-harm  Exposure to forces of nature  Conflict and terrorism  \
# Year
# 1990   0.376236                      0.005702                1.691716
#
#       Interpersonal violence  Neglected tropical diseases and malaria  \
# Year
# 1990                0.401639                                10.892887
#
#       Substance use disorders  Skin and subcutaneous diseases  \
# Year
# 1990                 0.180229                        0.529106
#
#       Enteric infections  Diabetes and kidney diseases  \
# Year
# 1990           12.070425                      1.036453
#
#       Cardiovascular diseases  Digestive diseases  Nutritional deficiencies  \
# Year
# 1990                  3.72111            1.603044                  5.127414
#
#       Respiratory infections and tuberculosis  Neonatal disorders  \
# Year
# 1990                                16.525927           11.693203
#
#       Chronic respiratory diseases  Other non-communicable diseases  \
# Year
# ...

# %%
df_world_low.tail(1)
# Out:
#       Self-harm  Exposure to forces of nature  Conflict and terrorism  \
# Year
# 2019   0.659365                       0.06996                0.928215
#
#       Interpersonal violence  Neglected tropical diseases and malaria  \
# Year
# 2019                 0.92832                                 8.570591
#
#       Substance use disorders  Skin and subcutaneous diseases  \
# Year
# 2019                  0.43706                        1.179124
#
#       Enteric infections  Diabetes and kidney diseases  \
# Year
# 2019            8.176397                       2.14677
#
#       Cardiovascular diseases  Digestive diseases  Nutritional deficiencies  \
# Year
# 2019                 6.594296             2.58752                   3.58115
#
#       Respiratory infections and tuberculosis  Neonatal disorders  \
# Year
# 2019                                11.719383            13.72551
#
#       Chronic respiratory diseases  Other non-communicable diseases  \
# Year
# ...

# %%
df_world_low.plot(figsize=(19,19))
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=10)

# %%
sorted = df.sort_values(by=["average"])
edted=sorted.loc[:, ~df.columns.isin(['Neglected tropical diseases and malaria', 'Skin and subcutaneous diseases','Enteric infections','Diabetes and kidney diseases','Cardiovascular diseases','Digestive diseases','Nutritional deficiencies','Respiratory infections and tuberculosis','Neonatal disorders','Chronic respiratory diseases','Maternal disorders','Unintentional injuries','Musculoskeletal disorders','Neoplasms','Mental disordersNeurological disorders','HIV/AIDS and sexually transmitted infections','Transport injuries','Sense organ diseases','Code','Self-harm','Conflict and terrorism','Interpersonal violence','Substance use disorders','Mental disorders','Unnamed: 30','Other non-communicable diseases','Neurological disorders','Unnamed: 29'])]
print(edted.head(10))
# Out:
#               Entity  Year  Exposure to forces of nature    average
# 3170           Haiti  2010                     69.702674 -69.135428
# 1250       Caribbean  2010                     47.198849 -47.737157
# 3338        Honduras  1998                     31.823329 -32.165015
# 6704       Sri Lanka  2004                     26.843275 -28.996958
# 7599       Venezuela  1999                     22.991904 -24.538569
# 4788         Myanmar  2008                     24.863083 -23.843059
# 5989           Samoa  2009                     14.560252 -16.985604
# 229   American Samoa  2009                     11.724860 -15.069192
# 4958       Nicaragua  1998                     13.783218 -14.324292
# 1747    Cook Islands  1997                     10.390604 -13.597730

# %%
edted_2=sorted.loc[:, ~df.columns.isin(['Neglected tropical diseases and malaria', 'Skin and subcutaneous diseases','Enteric infections','Diabetes and kidney diseases','Cardiovascular diseases','Digestive diseases','Nutritional deficiencies','Respiratory infections and tuberculosis','Neonatal disorders','Chronic respiratory diseases','Maternal disorders','Unintentional injuries','Musculoskeletal disorders','Neoplasms','Mental disordersNeurological disorders','HIV/AIDS and sexually transmitted infections','Transport injuries','Sense organ diseases','Code','Self-harm','Interpersonal violence','Substance use disorders','Mental disorders','Unnamed: 30','Other non-communicable diseases','Neurological disorders','Unnamed: 29'])]
print(edted_2.tail(10))
# Out:
#              Entity  Year  Exposure to forces of nature  \
# 6371        Somalia  2001                      0.016112
# 6372        Somalia  2002                      0.015399
# 6360        Somalia  1990                      0.000297
# 4981          Niger  1991                      0.000092
# 6373        Somalia  2003                      0.015331
# 6374        Somalia  2004                      0.189329
# 4985          Niger  1995                      0.000347
# 3099  Guinea-Bissau  1999                      0.000033
# 6375        Somalia  2005                      0.024071
# 6376        Somalia  2006                      0.074557
#
#       Conflict and terrorism    average
# 6371                0.339294  17.805356
# 6372                0.245873  18.244047
# 6360                2.220037  18.388227
# 4981                0.025559  18.396677
# 6373                0.426588  18.513152
# 6374                0.928281  18.608774
# 4985                0.041514  18.728781
# ...

# %%
from sklearn.cluster import KMeans

# %%
df_1990_2019_1=df_1990_2019.drop(['Code','Year'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14104/3970590713.py in <module>
# ----> 1 df_1990_2019_1=df_1990_2019.drop(['Code','Year'],axis=1)
#
# NameError: name 'df_1990_2019' is not defined

# %%
kmeans_model = KMeans(n_clusters=4, random_state=10).fit(df_1990_2019_1)

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df_1990_2019.corr(),annot=True, cbar=False, cmap='Blues', fmt='.1f')

# %%
data1=df_1990_2019[['Neglected tropical diseases and malaria', 'Enteric infections','Nutritional deficiencies','Respiratory infections and tuberculosis', 'Neonatal disorders',
                          'HIV/AIDS and sexually transmitted infections']]

# %%
sns.heatmap(data1.corr(),annot=True, cbar=False, cmap='Blues', fmt='.1f')
